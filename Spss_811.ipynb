# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from datetime import  datetime

# %%
ins = pd.read_csv(r'D:\UD\Sales_predict\data\Spss_8.1.csv', encoding='utf-8')
ins
# Out:
#        工业生产总值    利差
# 0     26.4050  0.73
# 1     26.1701  0.52
# 2     25.9351  0.41
# 3     25.7295  0.36
# 4     25.7001  0.50
# 5     25.3770  0.83
# 6     25.2889  0.67
# 7     25.2595  0.82
# 8     24.9952  1.20
# 9     24.9658  1.42
# 10    24.6134  1.49
# 11    24.1434  1.86
# 12    24.1728  2.39
# 13    24.1434  1.24
# 14    24.2903  1.72
# 15    24.7896  2.29
# 16    25.1714  1.73
# 17    25.5239  2.15
# 18    25.8176  2.75
# 19    26.0526  2.04
# 20    26.0232  2.10
# 21    26.5225  1.66
# 22    26.9337  1.33
# 23    27.1687  1.73
# 24    26.9337  1.93
# 25    27.3743  1.67
# 26    27.5212  1.08
# 27    27.5799  1.06
# 28    27.5505  1.51
# 29    27.4918  1.23
# ..        ...   ...
# 558  110.1428 -0.15
# 559  110.2365 -0.37
# 560  109.8273 -0.53
# 561  109.7437 -0.52
# 562  109.5274 -0.65
# 563  110.1754 -0.68
# 564  109.7791 -0.49
# 565  110.5181 -0.54
# 566  110.4036 -0.70
# 567  110.9530 -0.56
# 568  110.9686 -0.50
# 569  111.3551 -0.15
# 570  112.0024 -0.26
# ...

# %%
ins['date'] = pd.date_range('1/1/2018',periods=len(ins),freq='D')

# %%
a = np.var(ins['利差'][:int(len(ins)/2)])
b = np.var(ins['利差'][int(len(ins)/2):len(ins)])
#方差
print(a,b)
# Out:
# 3.425857454070064 1.7152678606136338

# %%
np.cov(ins['利差'])
# Out:
# array(2.8422178)

# %%
ins
# Out:
#        工业生产总值    利差       date
# 0     26.4050  0.73 2018-01-01
# 1     26.1701  0.52 2018-01-02
# 2     25.9351  0.41 2018-01-03
# 3     25.7295  0.36 2018-01-04
# 4     25.7001  0.50 2018-01-05
# 5     25.3770  0.83 2018-01-06
# 6     25.2889  0.67 2018-01-07
# 7     25.2595  0.82 2018-01-08
# 8     24.9952  1.20 2018-01-09
# 9     24.9658  1.42 2018-01-10
# 10    24.6134  1.49 2018-01-11
# 11    24.1434  1.86 2018-01-12
# 12    24.1728  2.39 2018-01-13
# 13    24.1434  1.24 2018-01-14
# 14    24.2903  1.72 2018-01-15
# 15    24.7896  2.29 2018-01-16
# 16    25.1714  1.73 2018-01-17
# 17    25.5239  2.15 2018-01-18
# 18    25.8176  2.75 2018-01-19
# 19    26.0526  2.04 2018-01-20
# 20    26.0232  2.10 2018-01-21
# 21    26.5225  1.66 2018-01-22
# 22    26.9337  1.33 2018-01-23
# 23    27.1687  1.73 2018-01-24
# 24    26.9337  1.93 2018-01-25
# 25    27.3743  1.67 2018-01-26
# 26    27.5212  1.08 2018-01-27
# 27    27.5799  1.06 2018-01-28
# 28    27.5505  1.51 2018-01-29
# ...

# %%
plt.plot(ins['利差'])

# %%
ins.describe()
# Out:
#            工业生产总值          利差
# count  588.000000  588.000000
# mean    64.749302    0.863044
# std     25.704488    1.685888
# min     24.143400   -6.510000
# 25%     43.770825    0.047500
# 50%     59.798200    0.995000
# 75%     85.090875    2.112500
# max    112.570400    3.850000

# %%
import statsmodels.datasets
